# %%
#Import pandas
import pandas as pd

# %%
#Create a data dictionary
data={'Position': ['GK','GK','GK', 'DF','DF','DF','MF','MF','MF','CF','CF','CF'],
       'Name': ['De Gea', 'Coutois', 'Allison', 'Chiellini','Ramos','Godin','Hazard','Kante','De Bruyne','Ronaldo','Messi','Neymar'],
       'Overall': ['91','88','89','89','91','90','91','90','92','94','93','92'],
       'Rank': ['1st','3rd','2nd','3rd','1st','2nd','2nd','3rd','1st','1st','2nd','3rd']}

# %%
#Create a Dataframe
fifa19=pd.DataFrame(data, columns=['Position','Name','Overall','Rank'])

# %%
fifa19
# Out:
#    Position       Name Overall Rank
# 0        GK     De Gea      91  1st
# 1        GK    Coutois      88  3rd
# 2        GK    Allison      89  2nd
# 3        DF  Chiellini      89  3rd
# 4        DF      Ramos      91  1st
# 5        DF      Godin      90  2nd
# 6        MF     Hazard      91  2nd
# 7        MF      Kante      90  3rd
# 8        MF  De Bruyne      92  1st
# 9        CF    Ronaldo      94  1st
# 10       CF      Messi      93  2nd
# 11       CF     Neymar      92  3rd

# %%
fifa19=fifa19.set_index(['Position','Rank'])

# %%
#Cheack if it is multiIndexed
fifa19.index
# Out:
# MultiIndex(levels=[['CF', 'DF', 'GK', 'MF'], ['1st', '2nd', '3rd']],
#            codes=[[2, 2, 2, 1, 1, 1, 3, 3, 3, 0, 0, 0], [0, 2, 1, 2, 0, 1, 1, 2, 0, 0, 1, 2]],
#            names=['Position', 'Rank'])

# %%
#Sort dataframe
fifa19.sort_index()
# Out:
#                     Name Overall
# Position Rank
# CF       1st     Ronaldo      94
#          2nd       Messi      93
#          3rd      Neymar      92
# DF       1st       Ramos      91
#          2nd       Godin      90
#          3rd   Chiellini      89
# GK       1st      De Gea      91
#          2nd     Allison      89
#          3rd     Coutois      88
# MF       1st   De Bruyne      92
#          2nd      Hazard      91
#          3rd       Kante      90

# %%
#Slice Goalkeeper and Midfielder rows
fifa19.loc[['GK','MF']]
# Out:
#                     Name Overall
# Position Rank
# GK       1st      De Gea      91
#          3rd     Coutois      88
#          2nd     Allison      89
# MF       2nd      Hazard      91
#          3rd       Kante      90
#          1st   De Bruyne      92

# %%
#Slice the highest rated players of all positions
fifa19.loc[(slice(None),'1st'),:]
# Out:
#                     Name Overall
# Position Rank
# GK       1st      De Gea      91
# DF       1st       Ramos      91
# MF       1st   De Bruyne      92
# CF       1st     Ronaldo      94

# %%
#slice 2nd rated players in all positions
fifa19.loc[(slice(None),'2nd'),:]
# Out:
#                   Name Overall
# Position Rank
# GK       2nd   Allison      89
# DF       2nd     Godin      90
# MF       2nd    Hazard      91
# CF       2nd     Messi      93

# %%
#Slice only GK
fifa19.loc['GK']
# Out:
#          Name Overall
# Rank
# 1st    De Gea      91
# 3rd   Coutois      88
# 2nd   Allison      89

# %%
#Slice the highest rated goalkeeper
fifa19.loc[('GK', '1st')]
# Out:
# Name       De Gea
# Overall        91
# Name: (GK, 1st), dtype: object

# %%
#Slice the overall attribute of the 2nd best gaolkeeper
fifa19.loc[('GK','2nd'), 'Overall']
# Out:
# '89'

# %%
#Adding an additional column
fifa19.loc[('GK','3rd'),['Name','Overall']]
# Out:
# Name       Coutois
# Overall         88
# Name: (GK, 3rd), dtype: object

# %%
fifa19.loc[['GK','MF']]
# Out:
#                     Name Overall
# Position Rank
# GK       1st      De Gea      91
#          3rd     Coutois      88
#          2nd     Allison      89
# MF       2nd      Hazard      91
#          3rd       Kante      90
#          1st   De Bruyne      92

# %%
#Slice the best GK and MF
fifa19.loc[(['GK','MF'],'1st'),:]
# Out:
#                     Name Overall
# Position Rank
# GK       1st      De Gea      91
# MF       1st   De Bruyne      92

# %%
fifa19.loc[(['GK','MF'],'3rd'), 'Name']
# Out:
# Position  Rank
# GK        3rd     Coutois
# MF        3rd       Kante
# Name: Name, dtype: object

# %%
#Inner level slicing
fifa19.loc[('GK',['1st','3rd']),:]
# Out:
#                   Name Overall
# Position Rank
# GK       1st    De Gea      91
#          3rd   Coutois      88

# %%
fifa19.loc[(['MF','CF'], '2nd'), :]
# Out:
#                  Name Overall
# Position Rank
# MF       2nd   Hazard      91
# CF       2nd    Messi      93

# %% [markdown]
# Next tutorial will be on Pivoting, Pivot tables, Stacking and Unstacking

# %% [markdown]
# pivoting is the process of reshaping dataframes so that it is easier to see the relationship between different columns

# %%
fifa19
# Out:
#                     Name Overall
# Position Rank
# GK       1st      De Gea      91
#          3rd     Coutois      88
#          2nd     Allison      89
# DF       3rd   Chiellini      89
#          1st       Ramos      91
#          2nd       Godin      90
# MF       2nd      Hazard      91
#          3rd       Kante      90
#          1st   De Bruyne      92
# CF       1st     Ronaldo      94
#          2nd       Messi      93
#          3rd      Neymar      92

# %%
fifa19['Category'] = ['100','90','90','80','90','100','80','100','90','80','100','80']

# %%
fifa19
# Out:
#                     Name Overall Category
# Position Rank
# GK       1st      De Gea      91      100
#          3rd     Coutois      88       90
#          2nd     Allison      89       90
# DF       3rd   Chiellini      89       80
#          1st       Ramos      91       90
#          2nd       Godin      90      100
# MF       2nd      Hazard      91       80
#          3rd       Kante      90      100
#          1st   De Bruyne      92       90
# CF       1st     Ronaldo      94       80
#          2nd       Messi      93      100
#          3rd      Neymar      92       80

# %%
fifa19
# Out:
#                     Name Overall Category
# Position Rank
# GK       1st      De Gea      91      100
#          3rd     Coutois      88       90
#          2nd     Allison      89       90
# DF       3rd   Chiellini      89       80
#          1st       Ramos      91       90
#          2nd       Godin      90      100
# MF       2nd      Hazard      91       80
#          3rd       Kante      90      100
#          1st   De Bruyne      92       90
# CF       1st     Ronaldo      94       80
#          2nd       Messi      93      100
#          3rd      Neymar      92       80

# %%
del fifa19['Category']

# %%
fifa19
# Out:
#                     Name Overall
# Position Rank
# GK       1st      De Gea      91
#          3rd     Coutois      88
#          2nd     Allison      89
# DF       3rd   Chiellini      89
#          1st       Ramos      91
#          2nd       Godin      90
# MF       2nd      Hazard      91
#          3rd       Kante      90
#          1st   De Bruyne      92
# CF       1st     Ronaldo      94
#          2nd       Messi      93
#          3rd      Neymar      92

# %%
fifa19.loc['GK']
# Out:
#          Name Overall
# Rank
# 1st    De Gea      91
# 3rd   Coutois      88
# 2nd   Allison      89

# %%
swapped = fifa19.swaplevel(0,1)
swapped
# Out:
#                     Name Overall
# Rank Position
# 1st  GK           De Gea      91
# 3rd  GK          Coutois      88
# 2nd  GK          Allison      89
# 3rd  DF        Chiellini      89
# 1st  DF            Ramos      91
# 2nd  DF            Godin      90
#      MF           Hazard      91
# 3rd  MF            Kante      90
# 1st  MF        De Bruyne      92
#      CF          Ronaldo      94
# 2nd  CF            Messi      93
# 3rd  CF           Neymar      92

# %% [markdown]
# ## Swapping Levels

# %% [markdown]
# Sometimes, after arriving at a multiindex, we want to change the positions of the indexes to make analysis easier. We do this by using <code>.swaplevel()</code>.

# %%
swapped = swapped.swaplevel(0,1)
swapped
# Out:
#                     Name Overall
# Rank Position
# 1st  GK           De Gea      91
# 3rd  GK          Coutois      88
# 2nd  GK          Allison      89
# 3rd  DF        Chiellini      89
# 1st  DF            Ramos      91
# 2nd  DF            Godin      90
#      MF           Hazard      91
# 3rd  MF            Kante      90
# 1st  MF        De Bruyne      92
#      CF          Ronaldo      94
# 2nd  CF            Messi      93
# 3rd  CF           Neymar      92

# %% [markdown]
# # Wine Reviews dataset

# %%
reviews = pd.read_csv('winemag-data-130k-v2.csv', index_col =0)
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129971 entries, 0 to 129970
# Data columns (total 13 columns):
# country                  129908 non-null object
# description              129971 non-null object
# designation              92506 non-null object
# points                   129971 non-null int64
# price                    120975 non-null float64
# province                 129908 non-null object
# region_1                 108724 non-null object
# region_2                 50511 non-null object
# taster_name              103727 non-null object
# taster_twitter_handle    98758 non-null object
# title                    129971 non-null object
# variety                  129970 non-null object
# winery                   129971 non-null object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 13.9+ MB

# %% [markdown]
# ## Question 1
# What is the median of the 'points' column in the 'reviews' Dataframe?

# %%
review_median = reviews['points'].median()
review_median
# Out:
# 88.0

# %% [markdown]
# ## Question 2
# What countries are represented in the dataset? (Your answer should not include any duplicates.)

# %%
countries = reviews['country'].unique()
countries
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %% [markdown]
# ## Question 3
# How often does each country appear in the dataset? Create a Series <code>reviews_per_country</code> mapping countries to the count of reviews of wines from that country.

# %%
reviews_per_country = reviews['country'].value_counts()
reviews_per_country
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %% [markdown]
# ## Question 4
# Create variable <code>centered_price</code> containing a version of the price column with the mean price subtracted.
#
# (Note: this 'centering' transformation is a common preprocessing step before applying various machine learning algorithms.)

# %%
mean_price = reviews.price.mean()
centered_price = reviews.price.map(lambda p: p - mean_price)
centered_price.head(10)
# Out:
# 0          NaN
# 1   -20.363389
# 2   -21.363389
# 3   -22.363389
# 4    29.636611
# 5   -20.363389
# 6   -19.363389
# 7   -11.363389
# 8   -23.363389
# 9    -8.363389
# Name: price, dtype: float64

# %% [markdown]
# ## Question 5
# I'm an economical wine buyer. Which wine is the "best bargain"? Create a variable `bargain_wine` with the title of the wine with the highest points-to-price ratio in the dataset.

# %%
points_price_ratio = (reviews['points']/reviews['price']).idxmax()
bargain_wine = reviews.loc[points_price_ratio, 'title']
bargain_wine
# Out:
# 'Bandit NV Merlot (California)'

# %% [markdown]
# ## Question 6
# There are only so many words you can use when describing a bottle of wine. Is a wine more likely to be "tropical" or "fruity"? Create a Series `descriptor_counts` counting how many times each of these two words appears in the description column in the dataset.

# %%
tropical = reviews.description.map(lambda d: 'tropical' in d).sum()
fruity = reviews.description.map(lambda d: 'fruity' in d).sum()
descriptor_counts = pd.Series([tropical, fruity], index=['tropical', 'fruity'])
descriptor_counts
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %% [markdown]
# ## Question 7
# We'd like to host these wine reviews on our website, but a rating system ranging from 80 to 100 points is too hard to understand - we'd like to translate them into simple star ratings. A score of 95 or higher counts as 3 stars, a score of at least 85 but less than 95 is 2 stars. Any other score is 1 star.
#
# Also, the Canadian Vintners Association bought a lot of ads on the site, so any wines from Canada should automatically get 3 stars, regardless of points.
#
# Create a series `star_ratings` with the number of stars corresponding to each review in the dataset.

# %%
def stars(row):
    if row.country=='Canada':
        return 3 
    elif row.points >=95:
        return 3 
    elif row.points >=85:
        return 2
    else:
        return 1


    
reviews['star_ratings']= reviews.apply(stars, axis='columns')
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# `Star_ratings` column has been added to the dataframe but we are not too sure it is doing exactly what it is meant to do. To check the accuracy of the function written, I use the `.sample()` method to select random portions of the dataframe.

# %%
reviews.sample(10)
# Out:
#          country                                        description  \
# 42538      Italy  A successful expression of Sauvignon Blanc, th...
# 4099   Australia  Spicy and floral on the nose, this is surprisi...
# 10798         US  It's not clear what Swanson means by the word ...
# 7625          US  This well-balanced, flavorful and medium-bodie...
# 99603    Austria  The slightest minty lift is perceptible on the...
# 49915  Argentina  Sophisticated barrel aromas of butterscotch, d...
# 14158    Romania  The Dreambird Pinot Noir is cheerful and brigh...
# 84620     France  This very complete wine displays a fine balanc...
# 83323         US  Cherry blossom and wild berries show on the no...
# 97743    Austria  Although the nose is restrained, fresh, ripe n...
#
#                              designation  points  price            province  \
# 42538                              Picol      90   28.0  Northeastern Italy
# ...

# %% [markdown]
# It appears it is working just fine.. but to be sure, I want to select every wine from Canada to inspect if indeed they all have 3 stars.

# %%
reviews.loc[reviews['country']=='Canada']
# Out:
#        country                                        description  \
# 454     Canada  An aromatic knockout with notes of peach, papa...
# 2616    Canada  A slightly earthy, spicy nose leads, followed ...
# 5129    Canada  The Okanagan has the capability to produce del...
# 5253    Canada  A fine companion to the winery's Cabernet Sauv...
# 5580    Canada  Intense flavors of mango, melon and apricot le...
# 5657    Canada  Sourced from a single vineyard on Oliver's Nor...
# 6465    Canada  Gorgeously aromatic with notes of freshly pres...
# 6863    Canada  Cab Franc makes a strong case for being top gu...
# 7125    Canada  This wine plays out broadly across the palate,...
# 7141    Canada  From the Canadian Okanagan, this stylish, well...
# 7504    Canada  This irresistible, lightly frizzante and utter...
# 7513    Canada  Produced from the estate vineyard's oldest vin...
# 7622    Canada  This off-dry wine is solid, with a mix of lemo...
# ...

# %%
#wines from Canada which have prices above $29
good_wine=reviews.loc[(reviews.country.isin(['Canada']) & (reviews.price>=30))]
good_wine
# Out:
#        country                                        description  \
# 454     Canada  An aromatic knockout with notes of peach, papa...
# 5129    Canada  The Okanagan has the capability to produce del...
# 5253    Canada  A fine companion to the winery's Cabernet Sauv...
# 6465    Canada  Gorgeously aromatic with notes of freshly pres...
# 7125    Canada  This wine plays out broadly across the palate,...
# 7779    Canada  Essentially a Bordeaux-style blend (just 4% Sy...
# 7801    Canada  This unique, port-style dessert wine fortifies...
# 7878    Canada  Smooth as silk and deeply concentrated, this o...
# 8230    Canada  This wine is the vinous equivalent of biting i...
# 8234    Canada  Harvested at 40.16 Brix and retaining a whoppi...
# 10003   Canada  This vibrantly aromatic wine brings generous n...
# 10715   Canada  This is the winery's superstar Bordeaux-style ...
# 10727   Canada  Dark and silky, this bursts open with ripe plu...
# ...

# %% [markdown]
# Get name and twitter handles of people who tasted the good wines from Canada

# %%
good_wine['taster_twitter_handle'].value_counts()
# Out:
# @paulgwine       91
# @wawinereport    28
# @suskostrzewa     7
# @JoeCz            5
# @laurbuzz         1
# Name: taster_twitter_handle, dtype: int64

# %% [markdown]
# # Grouping and Sorting

# %% [markdown]
# ## Question 1
# Who are the most common wine reviewers in the dataset? Create a Series whose index is the `taster_twitter_handle` category from the dataset, and whose values count how many reviews each person wrote.

# %%
reviews_written = reviews['taster_twitter_handle'].value_counts()
reviews_written.head(10)
# Out:
# @vossroger          25514
# @wineschach         15134
# @kerinokeefe        10776
# @vboone              9537
# @paulgwine           9532
# @mattkettmann        6332
# @JoeCz               5147
# @wawinereport        4966
# @gordone_cellars     4177
# @AnneInVino          3685
# Name: taster_twitter_handle, dtype: int64

# %%
revs=reviews.groupby(['taster_twitter_handle']).taster_twitter_handle.count()
revs
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# Name: taster_twitter_handle, dtype: int64

# %%
#Both methods result in the same output
revs2 = reviews.groupby('taster_twitter_handle').size()
revs2
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# dtype: int64

# %% [markdown]
# ## Question 2.
# What is the best wine I can buy for a given amount of money? Create a `Series` whose index is wine prices and whose values is the maximum number of points a wine costing that much was given in a review. Sort the values by price, ascending (so that `4.0` dollars is at the top and `3300.0` dollars is at the bottom).

# %%
ratings = reviews.loc[reviews.groupby('price')['points'].max().sort_index()]
ratings
# Out:
#      country                                        description  \
# 86        US  Vibrant aromas of ripe pear, white flowers and...
# 87        US  Softened tannins surround a light-bodied, lean...
# 88     Italy  Subdued aromas of French oak, toast and acacia...
# 91        US  This wine has a touch of perceptible sweetness...
# 91        US  This wine has a touch of perceptible sweetness...
# 91        US  This wine has a touch of perceptible sweetness...
# 91        US  This wine has a touch of perceptible sweetness...
# 92        US  All red Bordeaux varieties are represented in ...
# 93   Austria  Freshness characterizes the nose: green pear, ...
# 94        US  Barrel notes are prominent, with aromas of Cre...
# 94        US  Barrel notes are prominent, with aromas of Cre...
# 93   Austria  Freshness characterizes the nose: green pear, ...
# 94        US  Barrel notes are prominent, with aromas of Cre...
# 93   Austria  Freshness characterizes the nose: green pear, ...
# ...

# %% [markdown]
# ## Question 3.
# What are the minimum and maximum prices for each `variety` of wine? Create a `DataFrame` whose index is the `variety` category from the dataset and whose values are the `min` and `max` values thereof.

# %%
minmanx = reviews.groupby('variety').price.agg([min,max])
minmanx
# Out:
#                          min    max
# variety
# Abouriou                15.0   75.0
# Agiorgitiko             10.0   66.0
# Aglianico                6.0  180.0
# Aidani                  27.0   27.0
# Airen                    8.0   10.0
# Albana                  12.0   50.0
# Albanello               20.0   20.0
# Albariño                10.0   75.0
# Albarossa               40.0   40.0
# Aleatico                25.0   55.0
# Alfrocheiro             11.0   50.0
# Alicante                10.0   30.0
# Alicante Bouschet        7.0  150.0
# Aligoté                 13.0   36.0
# Alsace white blend      10.0   98.0
# Altesse                 15.0   19.0
# Alvarelhão              18.0   24.0
# Alvarinho                9.0   75.0
# Alvarinho-Chardonnay     9.0   15.0
# Ansonica                22.0   30.0
# Antão Vaz               11.0   30.0
# Apple                   25.0   33.0
# Aragonez                10.0   35.0
# Aragonês                14.0   70.0
# Argaman                 36.0   48.0
# ...

# %% [markdown]
# ## Question  4.
# What are the most expensive wine varieties? Create a variable `sorted_varieties` containing a copy of the dataframe from the previous question where varieties are sorted in descending order based on minimum price, then on maximum price (to break ties).

# %%
sort_varieties = reviews.groupby('variety')['points'].agg([min,max]).sort_values(by=['min','max'], ascending=True)
sort_varieties.head()
# Out:
#                     min  max
# variety
# Chancellor           80   81
# Airen                80   83
# Shiraz-Tempranillo   80   84
# Brachetto            80   86
# Chambourcin          80   87

# %% [markdown]
# ## Question 5.
# Create a `Series` whose index is reviewers and whose values is the average review score given out by that reviewer. Hint: you will need the `taster_name` and `points` columns.

# %%
tasters = reviews.groupby(['taster_name','taster_twitter_handle'])['points'].mean()
tasters
# Out:
# taster_name        taster_twitter_handle
# Anne Krebiehl MW   @AnneInVino              90.562551
# Christina Pickard  @winewchristina          87.833333
# Fiona Adams        @bkfiona                 86.888889
# Jeff Jenssen       @worldwineguys           88.319756
# Jim Gordon         @gordone_cellars         88.626287
# Joe Czerwinski     @JoeCz                   88.536235
# Kerin O’Keefe      @kerinokeefe             88.867947
# Lauren Buzzeo      @laurbuzz                87.739510
# Matt Kettmann      @mattkettmann            90.008686
# Michael Schachner  @wineschach              86.907493
# Mike DeSimone      @worldwineguys           89.101167
# Paul Gregutt       @paulgwine               89.082564
# Roger Voss         @vossroger               88.708003
# Sean P. Sullivan   @wawinereport            88.755739
# Susan Kostrzewa    @suskostrzewa            86.609217
# Virginie Boone     @vboone                  89.213379
# Name: points, dtype: float64

# %% [markdown]
# ## Question 6.
# What combination of countries and varieties are most common? Create a `Series` whose index is a `MultiIndex`of `{country, variety}` pairs. For example, a pinot noir produced in the US should map to `{"US", "Pinot Noir"}`. Sort the values in the `Series` in descending order based on wine count.

# %%
pairs = reviews.loc[reviews.groupby(['country', 'variety']).size().sort_values(ascending = True)]
pairs.head()
# Out:
#     country                                        description designation  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...    Avidagos
# 1  Portugal  This is ripe and fruity, a wine that is smooth...    Avidagos
# 1  Portugal  This is ripe and fruity, a wine that is smooth...    Avidagos
# 1  Portugal  This is ripe and fruity, a wine that is smooth...    Avidagos
# 1  Portugal  This is ripe and fruity, a wine that is smooth...    Avidagos
#
#    points  price province region_1 region_2 taster_name taster_twitter_handle  \
# 1      87   15.0    Douro      NaN      NaN  Roger Voss            @vossroger
# 1      87   15.0    Douro      NaN      NaN  Roger Voss            @vossroger
# 1      87   15.0    Douro      NaN      NaN  Roger Voss            @vossroger
# 1      87   15.0    Douro      NaN      NaN  Roger Voss            @vossroger
# 1      87   15.0    Douro      NaN      NaN  Roger Voss            @vossroger
#
# ...

# %% [markdown]
# # GeoPandas Analysis

# %%
import geopandas as gpd

# %% [markdown]
# Geopandas Analysis file formats include: `Shapefile (.shp)`, `GeoJSON`, `KML`, `GPKG` . We use `gdp.read_file()` to read any of these file formats. However, in order to read it without errors, make sure all other relevant files are also downloaded and kept in the same folder. Some of the relevant files have extensions like (`.cbg`,`.dbf`, `.shx`, `.prj`). If this is not done, python will raise <strong>Driver Error</strong>: `Set SHAPE_RESTORE_SHX config option to YES to restore or create it`.

# %%
kiva = gpd.read_file('kiva_loans.shp')
kiva.head()
# Out:
#    Partner ID                       Field Part                       sector  \
# 0           9  KREDIT Microfinance Institution  General Financial Inclusion
# 1           9  KREDIT Microfinance Institution  General Financial Inclusion
# 2           9  KREDIT Microfinance Institution  General Financial Inclusion
# 3           9  KREDIT Microfinance Institution  General Financial Inclusion
# 4           9  KREDIT Microfinance Institution  General Financial Inclusion
#
#                Loan Theme   country  amount                        geometry
# 0        Higher Education  Cambodia     450  POINT (102.8975098 13.6672596)
# 1  Vulnerable Populations  Cambodia   20275   POINT (102.989615 13.0286971)
# 2        Higher Education  Cambodia    9150   POINT (102.989615 13.0286971)
# 3  Vulnerable Populations  Cambodia  604950  POINT (105.3131185 12.0982918)
# 4              Sanitation  Cambodia     275  POINT (105.3131185 12.0982918)

# %% [markdown]
# We want to download a GeoDataFrame 'World' containing country boundaries

# %%
# This dataset is provided in GeoPandas
world_filepath = gpd.datasets.get_path('naturalearth_lowres')
world = gpd.read_file(world_filepath)
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  (POLYGON ((180 -16.06713266364245, 180 -16.555...
# 1  POLYGON ((33.90371119710453 -0.950000000000000...
# 2  POLYGON ((-8.665589565454809 27.65642588959236...
# 3  (POLYGON ((-122.84 49.00000000000011, -122.974...
# 4  (POLYGON ((-122.84 49.00000000000011, -120 49....

# %% [markdown]
# We are going to Use the `world` and `kiva` GeoDataFrames to visualize Kiva loan locations across the world.

# %% [markdown]
# The `plot()` method takes as (optional) input several parameters that can be used to customize the appearance. Most importantly, setting a value for `ax` ensures that all of the information is plotted on the same map.

# %%
ax = world.plot(figsize=(12,12), color ='gray', edgecolor='gainsboro',zorder=3)

# %% [markdown]
#  Select loans based in the Philippines.
#
# Next, you'll focus on loans that are based in the Philippines.  Use the next code cell to create a GeoDataFrame `Ph_loans` which contains all rows from `kiva` with loans that are based in the Philippines.

# %%
Ph_loans = kiva.loc[kiva['country']=='Philippines']
Ph_loans.head()
# Out:
#       Partner ID                  Field Part                       sector  \
# 2859         123  Alalay sa Kaunlaran (ASKI)  General Financial Inclusion
# 2860         123  Alalay sa Kaunlaran (ASKI)  General Financial Inclusion
# 2861         123  Alalay sa Kaunlaran (ASKI)  General Financial Inclusion
# 2862         123  Alalay sa Kaunlaran (ASKI)  General Financial Inclusion
# 2863         123  Alalay sa Kaunlaran (ASKI)  General Financial Inclusion
#
#      Loan Theme      country  amount                               geometry
# 2859    General  Philippines     400          POINT (121.739606 17.6422839)
# 2860    General  Philippines     400         POINT (121.7416934 17.6323524)
# 2861    General  Philippines     400  POINT (121.4666672 16.60000040000001)
# 2862    General  Philippines    6050          POINT (121.7333298 17.833334)
# 2863    General  Philippines     625         POINT (121.5179977 16.7236824)

# %% [markdown]
# Understand loans in Philippines
#
# loading a GeoDataFrame `PHL` containing boundaries for all islands in the Philippines.

# %%
# Load a KML file containing island boundaries
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
PHL = gpd.read_file("Philippines_AL258.kml", driver='KML')
PHL.head()
# Out:
#                                    Name Description  \
# 0  Autonomous Region in Muslim Mindanao
# 1                          Bicol Region
# 2                        Cagayan Valley
# 3                            Calabarzon
# 4                                Caraga
#
#                                             geometry
# 0  (POLYGON ((119.4668994 4.5871841, 119.4665294 ...
# 1  (POLYGON ((124.0457659 11.5786226, 124.0459356...
# 2  (POLYGON ((122.5158059 17.0443554, 122.515675 ...
# 3  (POLYGON ((120.4920249 14.0540312, 120.4920145...
# 4  (POLYGON ((126.4540073 8.243998599999999, 126....

# %% [markdown]
# Use the PHL and Ph_loans GeoDataFrames to visualize loans in the Philippines.

# %%
ax = PHL.plot(figsize=(12,12), color='whitesmoke', linestyle=':', edgecolor='green')
Ph_loans.plot(ax=ax, markersize=2)

# %% [markdown]
# Can you identify any islands where it might be useful to recruit new Field Partners? Do any islands currently look outside of Kiva's reach?

# %% [markdown]
# # EXERCISE

# %% [markdown]
# ## Introduction
#
# You are a bird conservation expert and want to understand migration patterns of purple martins.  In your research, you discover that these birds typically spend the summer breeding season in the eastern United States, and then migrate to South America for the winter.  But since this bird is under threat of endangerment, you'd like to take a closer look at the locations that these birds are more likely to visit.
#
# <center>
# <img src="https://i.imgur.com/qQcS0KM.png" width="1000"><br/>
# </center>
#
# There are several [protected areas](https://www.iucn.org/theme/protected-areas/about) in South America, which operate under special regulations to ensure that species that migrate (or live) there have the best opportunity to thrive.  You'd like to know if purple martins tend to visit these areas.  To answer this question, you'll use some recently collected data that tracks the year-round location of eleven different birds.
#
# Before you get started, load the data which is stored as a CVS to set everything up.

# %%
purple = pd.read_csv('purple_martin.csv')
purple.head()
# Out:
#              timestamp  location-long  location-lat  tag-local-identifier
# 0  2014-08-15 05:56:00     -88.146014     17.513049                 30448
# 1  2014-09-01 05:59:00     -85.243501     13.095782                 30448
# 2  2014-10-30 23:58:00     -62.906089     -7.852436                 30448
# 3  2014-11-15 04:59:00     -61.776826    -11.723898                 30448
# 4  2014-11-30 09:59:00     -61.241538    -11.612237                 30448

# %%
print('There are {} different bird species'.format(purple['tag-local-identifier'].nunique()))
# Out:
# There are 11 different bird species

# %% [markdown]
# There are 11 birds in the dataset, where each bird is identified by a unique value in the "tag-local-identifier" column. Each bird has several measurements, collected at different times of the year.

# %% [markdown]
# Use the next code cell to create a GeoDataFrame `birds`.
# - `birds` should have all of the columns from `birds_df`, along with a "geometry" column that contains Point objects with (longitude, latitude) locations.
# - Set the CRS of `birds` to `{'init': 'epsg:4326'}`.

# %%
birds = gpd.GeoDataFrame(purple, geometry=gpd.points_from_xy(purple['location-long'],purple['location-lat']))

# convert crs to epsg:4326

birds.crs = {'init': 'epsg:4326'}
birds.head()
# Out:
#              timestamp  location-long  location-lat  tag-local-identifier  \
# 0  2014-08-15 05:56:00     -88.146014     17.513049                 30448
# 1  2014-09-01 05:59:00     -85.243501     13.095782                 30448
# 2  2014-10-30 23:58:00     -62.906089     -7.852436                 30448
# 3  2014-11-15 04:59:00     -61.776826    -11.723898                 30448
# 4  2014-11-30 09:59:00     -61.241538    -11.612237                 30448
#
#                                  geometry
# 0   POINT (-88.14601429999998 17.5130487)
# 1   POINT (-85.24350059999998 13.0957817)
# 2  POINT (-62.9060891 -7.852436099999998)
# 3  POINT (-61.77682579999999 -11.7238981)
# 4         POINT (-61.2415383 -11.6122369)

# %% [markdown]
# ## Plot the data.
#
# Next, we load in the `'naturalearth_lowres'` dataset from GeoPandas, and set `americas` to a GeoDataFrame containing the boundaries of all countries in the Americas (both North and South America).  Run the next code cell without changes.

# %%
path = gpd.datasets.get_path('naturalearth_lowres')
world = gpd.read_file (path)
america = world.loc[world.continent.isin(['North America', 'South America'])]
america.head()
# Out:
#       pop_est      continent                      name iso_a3  gdp_md_est  \
# 3    35623680  North America                    Canada    CAN   1674000.0
# 4   326625791  North America  United States of America    USA  18560000.0
# 9    44293293  South America                 Argentina    ARG    879400.0
# 10   17789267  South America                     Chile    CHL    436100.0
# 16   10646714  North America                     Haiti    HTI     19340.0
#
#                                              geometry
# 3   (POLYGON ((-122.84 49.00000000000011, -122.974...
# 4   (POLYGON ((-122.84 49.00000000000011, -120 49....
# 9   (POLYGON ((-68.63401022758323 -52.636370458874...
# 10  (POLYGON ((-68.63401022758323 -52.636370458874...
# 16  POLYGON ((-71.71236141629296 19.71445587816736...

# %% [markdown]
# Use the next code cell to create a single plot that shows both: (1) the country boundaries in the `americas` GeoDataFrame, and (2) all of the points in the `birds_gdf` GeoDataFrame.
#
# Don't worry about any special styling here; just create a preliminary plot, as a quick sanity check that all of the data was loaded properly.  In particular, you don't have to worry about color-coding the points to differentiate between birds, and you don't have to differentiate starting points from ending points.  We'll do that in the next part of the exercise.

# %%
ax = america.plot(figsize=(10,10), edgecolor='whitesmoke', color='lightgray')
birds.plot(markersize=1, color ='blue', ax=ax)

# %% [markdown]
# ## Where does each bird start and end its journey? (Part 1)
#
# Now, we're ready to look more closely at each bird's path. create two GeoDataFrames:
# - `path_gdf` contains LineString objects that show the path of each bird.  It uses the `LineString()` method to create a LineString object from a list of Point objects.
# - `start_gdf` contains the starting points for each bird.

# %% [markdown]
# LineString has to be imported from `shapely.geometry`

# %%
# GeoDataFrame showing path for each bird
from shapely.geometry import LineString
path_df = birds.groupby('tag-local-identifier')['geometry'].apply(list).apply(lambda x: LineString(x)).reset_index()
path_gdf = gpd.GeoDataFrame(path_df, geometry = path_df.geometry)
path_gdf.crs={'init': 'epsg:4326'}
path_gdf.head()
# Out:
#    tag-local-identifier                                           geometry
# 0                 30048  LINESTRING (-90.1299245 20.7324163, -56.293942...
# 1                 30054  LINESTRING (-93.60860759999998 46.505630200000...
# 2                 30198  LINESTRING (-80.3103606 25.9254455, -88.146080...
# 3                 30263  LINESTRING (-76.78146219999998 42.992085, -62....
# 4                 30275  LINESTRING (-76.78213459999998 42.9920688, -60...

# %%
# GeoDataFrame showing the starting point of each bird
start_df = birds.groupby('tag-local-identifier')['geometry'].apply(list).apply(lambda x : x[0]).reset_index()
start_gdf = gpd.GeoDataFrame(start_df, geometry = start_df.geometry)
start_gdf.crs={'init':'espg:4326'}
start_gdf.head()
# Out:
#    tag-local-identifier                                      geometry
# 0                 30048                POINT (-90.1299245 20.7324163)
# 1                 30054  POINT (-93.60860759999998 46.50563020000001)
# 2                 30198                POINT (-80.3103606 25.9254455)
# 3                 30263          POINT (-76.78146219999998 42.992085)
# 4                 30275         POINT (-76.78213459999998 42.9920688)

# %% [markdown]
# Use the next code cell to create a GeoDataFrame `end_gdf` containing the final location of each bird.
# - The format should be identical to that of `start_gdf`, with two columns ("tag-local-identifier" and "geometry"), where the "geometry" column contains Point objects.
# - Set the CRS of `end_gdf` to `{'init': 'epsg:4326'}`.

# %%
end_df = birds.groupby('tag-local-identifier')['geometry'].apply(list).apply(lambda x:x[-1]).reset_index()
end_gdf= gpd.GeoDataFrame(end_df, geometry=end_df.geometry)
end_gdf.crs={'init':'epsg:4326'}
end_gdf.head()
# Out:
#    tag-local-identifier                                       geometry
# 0                 30048                 POINT (-47.5363204 -4.4375763)
# 1                 30054  POINT (-62.47913810000001 -5.038396400000001)
# 2                 30198                 POINT (-57.4641684 -2.7761655)
# 3                 30263          POINT (-50.192297 -5.705042400000001)
# 4                 30275                POINT (-57.7040429 -16.7233589)

# %% [markdown]
# ## Where does each bird start and end its journey? (Part 2)
#
# Use the GeoDataFrames from the question above (`path_gdf`, `start_gdf`, and `end_gdf`) to visualize the paths of all birds on a single map.  You may also want to use the `americas` GeoDataFrame.

# %%
ax = america.plot(figsize=(10,10), color='whitesmoke', edgecolor='lightgray')
path_gdf.plot(markersize=1, color='yellow', ax=ax)
start_gdf.plot(markersize=5, color='green',ax=ax)
end_gdf.plot(markersize=5, color='red', ax=ax)
